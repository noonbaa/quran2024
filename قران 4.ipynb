# %%
import json
import os
import re

# %%
pip install texttable
# Out:
# Requirement already satisfied: texttable in c:\users\basne\anaconda3\lib\site-packages (1.6.7)Note: you may need to restart the kernel to use updated packages.

# %%
import  texttable

# %%
from texttable import Texttable

# %%
surahs = {}

# %%
import os
folder_name = 'C:\\Users\\basne\\Desktop\\quranjson-master\\source\\surah'
file_names = os.listdir(folder_name)

# %%
for file_name in file_names:
    if file_name.endswith('.json'):
        with open(os.path.join(folder_name, file_name), encoding='utf-8') as f:
         data = json.load(f)

# %%
with open('C:/Users/basne/Desktop/quranjson-master/source\surah.json', 'r', encoding='utf-8' ) as f:
   data = json.load(f)

# %%
table = Texttable()
table.set_cols_align(["l","c","r"])
table.set_cols_valign(["t","m","b"])
for surah in data:
    name_surah = surah['titleAr']
    juz = surah['index']
    ayeh = surah['count']
    table.header(["سوره","جزء","آیه"])

    table = texttable.Texttable()
    table.add_row([name_surah, juz,ayeh])
   
    print(table.draw())
# Out:
# +---------+---+---+
# | الفاتحة | 1 | 7 |
# +---------+---+---+
# +--------+---+-----+
# | البقرة | 2 | 286 |
# +--------+---+-----+
# +----------+---+-----+
# | آل عمران | 3 | 200 |
# +----------+---+-----+
# +--------+---+-----+
# | النساء | 4 | 176 |
# +--------+---+-----+
# +---------+---+-----+
# | المائدة | 5 | 120 |
# +---------+---+-----+
# +---------+---+-----+
# | الأنعام | 6 | 165 |
# +---------+---+-----+
# +---------+---+-----+
# | الأعراف | 7 | 206 |
# +---------+---+-----+
# +---------+---+----+
# | الأنفال | 8 | 75 |
# +---------+---+----+
# +--------+---+-----+
# | التوبة | 9 | 129 |
# +--------+---+-----+
# +------+----+-----+
# | يونس | 10 | 109 |
# +------+----+-----+
# +-----+----+-----+
# | هود | 11 | 123 |
# +-----+----+-----+
# +------+----+-----+
# | يوسف | 12 | 111 |
# +------+----+-----+
# +-------+----+----+
# | الرعد | 13 | 43 |
# +-------+----+----+
# +---------+----+----+
# | إبراهيم | 14 | 52 |
# +---------+----+----+
# +-------+----+----+
# | الحجر | 15 | 99 |
# +-------+----+----+
# +-------+----+-----+
# | النحل | 16 | 128 |
# +-------+----+-----+
# +---------+----+-----+
# | الإسراء | 17 | 111 |
# +---------+----+-----+
# +-------+----+-----+
# | الكهف | 18 | 110 |
# +-------+----+-----+
# +------+----+----+
# | مريم | 19 | 98 |
# +------+----+----+
# +----+----+-----+
# | طه | 20 | 135 |
# +----+----+-----+
# +----------+----+-----+
# | الأنبياء | 21 | 112 |
# +----------+----+-----+
# +------+----+----+
# | الحج | 22 | 78 |
# +------+----+----+
# +----------+----+-----+
# | المؤمنون | 23 | 118 |
# +----------+----+-----+
# +-------+----+----+
# | النور | 24 | 64 |
# +-------+----+----+
# +---------+----+----+
# | الفرقان | 25 | 77 |
# +---------+----+----+
# +---------+----+-----+
# | الشعراء | 26 | 227 |
# +---------+----+-----+
# +-------+----+----+
# | النمل | 27 | 93 |
# +-------+----+----+
# +-------+----+----+
# | القصص | 28 | 88 |
# +-------+----+----+
# +----------+----+----+
# | العنكبوت | 29 | 69 |
# +----------+----+----+
# +-------+----+----+
# | الروم | 30 | 60 |
# +-------+----+----+
# +-------+----+----+
# | لقمان | 31 | 34 |
# +-------+----+----+
# +--------+----+----+
# | السجدة | 32 | 30 |
# +--------+----+----+
# +---------+----+----+
# | الأحزاب | 33 | 73 |
# +---------+----+----+
# +-----+----+----+
# | سبأ | 34 | 54 |
# +-----+----+----+
# +------+----+----+
# | فاطر | 35 | 45 |
# +------+----+----+
# +----+----+----+
# | يس | 36 | 83 |
# +----+----+----+
# +---------+----+-----+
# | الصافات | 37 | 182 |
# +---------+----+-----+
# +---+----+----+
# | ص | 38 | 88 |
# +---+----+----+
# +-------+----+----+
# | الزمر | 39 | 75 |
# +-------+----+----+
# +------+----+----+
# | غافر | 40 | 85 |
# +------+----+----+
# +------+----+----+
# | فصلت | 41 | 54 |
# +------+----+----+
# +--------+----+----+
# | الشورى | 42 | 53 |
# +--------+----+----+
# +--------+----+----+
# | الزخرف | 43 | 89 |
# +--------+----+----+
# +--------+----+----+
# | الدخان | 44 | 59 |
# +--------+----+----+
# +---------+----+----+
# | الجاثية | 45 | 37 |
# +---------+----+----+
# +---------+----+----+
# | الأحقاف | 46 | 35 |
# +---------+----+----+
# +------+----+----+
# | محمد | 47 | 38 |
# +------+----+----+
# +-------+----+----+
# | الفتح | 48 | 29 |
# +-------+----+----+
# +---------+----+----+
# | الحجرات | 49 | 18 |
# +---------+----+----+
# +---+----+----+
# | ق | 50 | 45 |
# +---+----+----+
# +----------+----+----+
# | الذاريات | 51 | 60 |
# +----------+----+----+
# +-------+----+----+
# | الطور | 52 | 49 |
# +-------+----+----+
# +-------+----+----+
# | النجم | 53 | 62 |
# +-------+----+----+
# +-------+----+----+
# | القمر | 54 | 55 |
# +-------+----+----+
# +--------+----+----+
# | الرحمن | 55 | 78 |
# +--------+----+----+
# +---------+----+----+
# | الواقعة | 56 | 96 |
# +---------+----+----+
# +--------+----+----+
# | الحديد | 57 | 29 |
# +--------+----+----+
# +----------+----+----+
# | المجادلة | 58 | 22 |
# +----------+----+----+
# +-------+----+----+
# | الحشر | 59 | 24 |
# +-------+----+----+
# +----------+----+----+
# | الممتحنة | 60 | 13 |
# +----------+----+----+
# +------+----+----+
# | الصف | 61 | 14 |
# +------+----+----+
# +--------+----+----+
# | الجمعة | 62 | 11 |
# +--------+----+----+
# +-----------+----+----+
# | المنافقون | 63 | 11 |
# +-----------+----+----+
# +---------+----+----+
# | التغابن | 64 | 18 |
# +---------+----+----+
# +--------+----+----+
# | الطلاق | 65 | 12 |
# +--------+----+----+
# +---------+----+----+
# | التحريم | 66 | 12 |
# +---------+----+----+
# +-------+----+----+
# | الملك | 67 | 30 |
# +-------+----+----+
# +-------+----+----+
# | القلم | 68 | 52 |
# +-------+----+----+
# +--------+----+----+
# | الحاقة | 69 | 52 |
# +--------+----+----+
# +---------+----+----+
# | المعارج | 70 | 44 |
# +---------+----+----+
# +-----+----+----+
# | نوح | 71 | 28 |
# +-----+----+----+
# +------+----+----+
# | الجن | 72 | 28 |
# +------+----+----+
# +--------+----+----+
# | المزمل | 73 | 20 |
# +--------+----+----+
# +--------+----+----+
# | المدثر | 74 | 56 |
# +--------+----+----+
# +---------+----+----+
# | القيامة | 75 | 40 |
# +---------+----+----+
# +---------+----+----+
# | الإنسان | 76 | 31 |
# +---------+----+----+
# +----------+----+----+
# | المرسلات | 77 | 50 |
# +----------+----+----+
# +-------+----+----+
# | النبأ | 78 | 40 |
# +-------+----+----+
# +----------+----+----+
# | النازعات | 79 | 46 |
# +----------+----+----+
# +-----+----+----+
# | عبس | 80 | 42 |
# +-----+----+----+
# +---------+----+----+
# | التكوير | 81 | 29 |
# +---------+----+----+
# +----------+----+----+
# | الإنفطار | 82 | 19 |
# +----------+----+----+
# +----------+----+----+
# | المطففين | 83 | 36 |
# +----------+----+----+
# +----------+----+----+
# | الإنشقاق | 84 | 25 |
# +----------+----+----+
# +--------+----+----+
# | البروج | 85 | 22 |
# +--------+----+----+
# +--------+----+----+
# | الطارق | 86 | 17 |
# +--------+----+----+
# +--------+----+----+
# | الأعلى | 87 | 19 |
# +--------+----+----+
# +---------+----+----+
# | الغاشية | 88 | 26 |
# +---------+----+----+
# +-------+----+----+
# | الفجر | 89 | 30 |
# +-------+----+----+
# +-------+----+----+
# | البلد | 90 | 20 |
# +-------+----+----+
# +-------+----+----+
# | الشمس | 91 | 15 |
# +-------+----+----+
# +-------+----+----+
# | الليل | 92 | 21 |
# +-------+----+----+
# +-------+----+----+
# | الضحى | 93 | 11 |
# +-------+----+----+
# +-------+----+---+
# | الشرح | 94 | 8 |
# +-------+----+---+
# +-------+----+---+
# | التين | 95 | 8 |
# +-------+----+---+
# +-------+----+----+
# | العلق | 96 | 19 |
# +-------+----+----+
# +-------+----+---+
# | القدر | 97 | 5 |
# +-------+----+---+
# +--------+----+---+
# | البينة | 98 | 8 |
# +--------+----+---+
# +---------+----+---+
# | الزلزلة | 99 | 8 |
# +---------+----+---+
# +----------+-----+----+
# | العاديات | 100 | 11 |
# +----------+-----+----+
# +---------+-----+----+
# | القارعة | 101 | 11 |
# +---------+-----+----+
# +---------+-----+---+
# | التكاثر | 102 | 8 |
# +---------+-----+---+
# +-------+-----+---+
# | العصر | 103 | 3 |
# +-------+-----+---+
# +--------+-----+---+
# | الهمزة | 104 | 9 |
# +--------+-----+---+
# +-------+-----+---+
# | الفيل | 105 | 5 |
# +-------+-----+---+
# +------+-----+---+
# | قريش | 106 | 4 |
# +------+-----+---+
# +---------+-----+---+
# | الماعون | 107 | 7 |
# +---------+-----+---+
# +--------+-----+---+
# | الكوثر | 108 | 3 |
# +--------+-----+---+
# +----------+-----+---+
# | الكافرون | 109 | 6 |
# +----------+-----+---+
# +-------+-----+---+
# | النصر | 110 | 3 |
# +-------+-----+---+
# +-------+-----+---+
# | المسد | 111 | 5 |
# +-------+-----+---+
# +---------+-----+---+
# | الإخلاص | 112 | 4 |
# +---------+-----+---+
# +-------+-----+---+
# | الفلق | 113 | 5 |
# +-------+-----+---+
# +-------+-----+---+
# | الناس | 114 | 6 |
# +-------+-----+---+

# %%
word_count = {
    'ايهاالذين امنوا': 0,
    'قل': 0,
    'نجم': 0,
    'صيام': 0
}

# %%
import os
import json
from texttable import Texttable

# مسیر فولدر حاوی فایل‌های JSON
folder_name = 'C:\\Users\\basne\\Desktop\\quranjson-master\\source\\surah'
file_names = os.listdir(folder_name)

# ایجاد جدول برای نمایش داده‌ها
table = Texttable()
table.set_cols_align(["l", "c", "r"])
table.set_cols_valign(["t", "m", "b"])
table.header(["سوره", "جزء", "آیه"])

# تعریف دیکشنری برای شمارش کلمات
word_count = {
    'ايهاالذين امنوا': 0,
    'قل': 0,
    'نجم': 0,
    'صيام': 0
}

# حلقه برای پردازش هر فایل JSON در فولدر
for file_name in file_names:
    if file_name.endswith('.json'):
        file_path = os.path.join(folder_name, file_name)
        
        # بارگذاری داده‌های JSON از هر فایل
        with open(file_path, encoding='utf-8') as f:
            data = json.load(f)
        
        # بررسی نوع داده‌ها در هر سوره
        if isinstance(data, dict):  # بررسی اینکه داده‌ها دیکشنری هستند
            name_surah = data.get('titleAr', 'نام سوره موجود نیست')  # نام سوره
            juz = data.get('index', 'جزء موجود نیست')  # جزء
            ayeh = data.get('count', 'آیه موجود نیست')  # تعداد آیه‌ها
            
            # افزودن داده‌ها به جدول
            table.add_row([name_surah, juz, ayeh])
            
            # شمارش کلمات در آیات
            verses = data.get('verses', [])  # فرض بر این است که آیات در کلید 'verses' قرار دارند
            for verse in verses:
                text = verse  # آیه به صورت رشته است
                for word in word_count.keys():
                    word_count[word] += text.count(word)
        else:
            print(f"داده اشتباه است: {data}")

# چاپ جدول نهایی
print(table.draw())

# چاپ آمار کلمات
for word, count in word_count.items():
    print(f"تعداد کلمه '{word}': {count}")
# Out:
# +---------------------+-----+-----+
# |        سوره         | جزء | آیه |
# +=====================+=====+=====+
# | نام سوره موجود نیست |  1  |   7 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 10  | 109 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 100 |  11 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 101 |  11 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 102 |   8 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 103 |   3 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 104 |   9 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 105 |   5 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 106 |   4 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 107 |   7 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 108 |   3 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 109 |   6 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 11  | 123 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 110 |   3 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 111 |   5 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 112 |   4 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 113 |   5 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 114 |   6 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 12  | 111 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 13  |  43 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 14  |  52 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 15  |  99 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 16  | 128 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 17  | 111 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 18  | 110 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 19  |  98 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست |  2  | 286 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 20  | 135 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 21  | 112 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 22  |  78 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 23  | 118 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 24  |  64 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 25  |  77 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 26  | 227 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 27  |  93 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 28  |  88 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 29  |  69 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست |  3  | 200 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 30  |  60 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 31  |  34 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 32  |  30 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 33  |  73 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 34  |  54 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 35  |  45 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 36  |  83 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 37  | 182 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 38  |  88 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 39  |  75 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست |  4  | 176 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 40  |  85 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 41  |  54 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 42  |  53 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 43  |  89 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 44  |  59 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 45  |  37 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 46  |  35 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 47  |  38 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 48  |  29 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 49  |  18 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست |  5  | 120 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 50  |  45 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 51  |  60 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 52  |  49 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 53  |  62 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 54  |  55 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 55  |  78 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 56  |  96 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 57  |  29 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 58  |  22 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 59  |  24 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست |  6  | 165 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 60  |  13 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 61  |  14 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 62  |  11 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 63  |  11 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 64  |  18 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 65  |  12 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 66  |  12 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 67  |  30 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 68  |  52 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 69  |  52 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست |  7  | 206 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 70  |  44 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 71  |  28 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 72  |  28 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 73  |  20 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 74  |  56 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 75  |  40 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 76  |  31 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 77  |  50 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 78  |  40 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 79  |  46 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست |  8  |  75 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 80  |  42 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 81  |  29 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 82  |  19 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 83  |  36 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 84  |  25 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 85  |  22 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 86  |  17 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 87  |  19 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 88  |  26 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 89  |  30 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست |  9  | 129 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 90  |  20 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 91  |  15 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 92  |  21 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 93  |  11 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 94  |   8 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 95  |   8 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 96  |  19 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 97  |   5 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 98  |   8 |
# +---------------------+-----+-----+
# | نام سوره موجود نیست | 99  |   8 |
# +---------------------+-----+-----+
# تعداد کلمه 'ايهاالذين امنوا': 0
# تعداد کلمه 'قل': 0
# تعداد کلمه 'نجم': 0
# تعداد کلمه 'صيام': 0

# %%
print(type(word_count))
# Out:
# <class 'dict'>

# %%
for i in range(1, 115):
      with open(os.path.join(folder_name, file_name), encoding='utf-8') as f:
         data = json.load(f)

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
print(data)
# Out:
# {'index': '099', 'name': 'al-Zalzalah', 'verse': {'verse_0': 'بِسْمِ اللَّهِ الرَّحْمَٰنِ الرَّحِيمِ', 'verse_1': 'إِذَا زُلْزِلَتِ ٱلْأَرْضُ زِلْزَالَهَا', 'verse_2': 'وَأَخْرَجَتِ ٱلْأَرْضُ أَثْقَالَهَا', 'verse_3': 'وَقَالَ ٱلْإِنسَٰنُ مَا لَهَا', 'verse_4': 'يَوْمَئِذٍۢ تُحَدِّثُ أَخْبَارَهَا', 'verse_5': 'بِأَنَّ رَبَّكَ أَوْحَىٰ لَهَا', 'verse_6': 'يَوْمَئِذٍۢ يَصْدُرُ ٱلنَّاسُ أَشْتَاتًۭا لِّيُرَوْا۟ أَعْمَٰلَهُمْ', 'verse_7': 'فَمَن يَعْمَلْ مِثْقَالَ ذَرَّةٍ خَيْرًۭا يَرَهُۥ', 'verse_8': 'وَمَن يَعْمَلْ مِثْقَالَ ذَرَّةٍۢ شَرًّۭا يَرَهُۥ'}, 'count': 8, 'juz': [{'index': '30', 'verse': {'start': 'verse_1', 'end': 'verse_8'}}]}

# %%
print(type(ayah))
# Out:
# <class 'str'>

# %%
print(ayah)
# Out:
# {'verse_0': 'بِسْمِ اللَّهِ الرَّحْمَٰنِ الرَّحِيمِ', 'verse_1': 'إِذَا زُلْزِلَتِ ٱلْأَرْضُ زِلْزَالَهَا', 'verse_2': 'وَأَخْرَجَتِ ٱلْأَرْضُ أَثْقَالَهَا', 'verse_3': 'وَقَالَ ٱلْإِنسَٰنُ مَا لَهَا', 'verse_4': 'يَوْمَئِذٍۢ تُحَدِّثُ أَخْبَارَهَا', 'verse_5': 'بِأَنَّ رَبَّكَ أَوْحَىٰ لَهَا', 'verse_6': 'يَوْمَئِذٍۢ يَصْدُرُ ٱلنَّاسُ أَشْتَاتًۭا لِّيُرَوْا۟ أَعْمَٰلَهُمْ', 'verse_7': 'فَمَن يَعْمَلْ مِثْقَالَ ذَرَّةٍ خَيْرًۭا يَرَهُۥ', 'verse_8': 'وَمَن يَعْمَلْ مِثْقَالَ ذَرَّةٍۢ شَرًّۭا يَرَهُۥ'}

# %%
# فرض بر این است که 'data' یک دیکشنری است که در آن هر کلید یک آیه است
# word_count یک دیکشنری است که کلمات مورد نظر را به عنوان کلید و مقدار اولیه صفر دارد
word_count = {
    'ايهاالذين امنوا': 0,
    'قل': 0,
    'نجم': 0,
    'صيام': 0
}

# شمارش کلمات در آیه‌ها
for key, ayah in data.items():
    if isinstance(ayah, str):  # اگر ayah یک رشته است
        text = ayah.strip()  # حذف فاصله‌های اضافی در ابتدا و انتهای متن
        # شمارش کلمات
        for word in word_count.keys():
            word_count[word] += text.count(word)
    else:
        print(f"آیه '{key}' به‌طور صحیح به‌عنوان رشته شناسایی نشد. نوع داده: {type(ayah)}")

# چاپ آمار کلمات مورد نظر
print(f"تعداد کلمه 'ايهاالذين امنوا': {word_count['ايهاالذين امنوا']}")
print(f"تعداد کلمه 'قل': {word_count['قل']}")
print(f"تعداد کلمه 'نجم': {word_count['نجم']}")
print(f"تعداد کلمه 'صيام': {word_count['صيام']}")
# Out:
# آیه 'verse' به‌طور صحیح به‌عنوان رشته شناسایی نشد. نوع داده: <class 'dict'>
# آیه 'count' به‌طور صحیح به‌عنوان رشته شناسایی نشد. نوع داده: <class 'int'>
# آیه 'juz' به‌طور صحیح به‌عنوان رشته شناسایی نشد. نوع داده: <class 'list'>
# تعداد کلمه 'ايهاالذين امنوا': 0
# تعداد کلمه 'قل': 0
# تعداد کلمه 'نجم': 0
# تعداد کلمه 'صيام': 0
